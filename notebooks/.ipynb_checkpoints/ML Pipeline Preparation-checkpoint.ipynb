# %% [markdown]
# # ML Pipeline Preparation
# Follow the instructions below to help you create your ML pipeline.
# ### 1. Import libraries and load data from database.
# - Import Python libraries
# - Load dataset from database with [`read_sql_table`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_sql_table.html)
# - Define feature and target variables X and Y

# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import nltk
import shap
import matplotlib.patches as mpatches
import plotly.express as px

from datetime import datetime
from sqlalchemy import create_engine
nltk.download(['punkt', 'wordnet', 'averaged_perceptron_tagger'])
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

from sklearn.pipeline import Pipeline
from sklearn.multioutput import MultiOutputClassifier
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer,TfidfVectorizer
from sklearn.decomposition import PCA, TruncatedSVD
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, f1_score, make_scorer, ConfusionMatrixDisplay, classification_report
from sklearn.model_selection import cross_val_score, RandomizedSearchCV
from lightgbm import LGBMClassifier, plot_importance
from sklearn import set_config                      # to change the display

from lime import lime_text
from lime.lime_text import LimeTextExplainer
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Chris
# [nltk_data]     Cochet\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Chris
# [nltk_data]     Cochet\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Chris Cochet\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
# load data from database
engine = create_engine('sqlite:///data/disaster-message.db')

df = pd.read_sql_query("SELECT * FROM messages", con = engine)
df = df.set_index('id')
X = df.drop('genre', axis = 1)
Y = df.iloc[:,2]

# %%
df['message'].head()
# Out:
# id
# 2     Weather update - a cold front from Cuba that c...
# 7               Is the Hurricane over or is it not over
# 8                       Looking for someone but no name
# 9     UN reports Leogane 80-90 destroyed. Only Hospi...
# 12    says: west side of Haiti, rest of the country ...
# Name: message, dtype: object

# %%
# inspect the df, X, Y dataframes
display(df.head(2), X.head(2), Y.head(2))
# Out:
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
#
#                                              original   genre  related  \
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...  direct        1
# 7                  Cyclone nan fini osinon li pa fini  direct        1
#
#     request  offer  aid_related  medical_help  medical_products  \
# id
# 2         0      0            0             0                 0
# 7         0      0            1             0                 0
#
#     search_and_rescue  ...  aid_centers  other_infrastructure  \
# id                     ...
# 2                   0  ...            0                     0
# 7                   0  ...            0                     0
#
#     weather_related  floods  storm  fire  earthquake  cold  other_weather  \
# id
# 2                 0       0      0     0           0     0              0
# 7                 1       0      1     0           0     0              0
#
#     direct_report
# id
# 2               0
# 7               0
#
# [2 rows x 39 columns]
#                                               message  \
# id
# 2   Weather update - a cold front from Cuba that c...
# 7             Is the Hurricane over or is it not over
#
#                                              original  related  request  \
# id
# 2   Un front froid se retrouve sur Cuba ce matin. ...        1        0
# 7                  Cyclone nan fini osinon li pa fini        1        0
#
#     offer  aid_related  medical_help  medical_products  search_and_rescue  \
# id
# 2       0            0             0                 0                  0
# 7       0            1             0                 0                  0
#
#     security  ...  aid_centers  other_infrastructure  weather_related  floods  \
# id            ...
# 2          0  ...            0                     0                0       0
# 7          0  ...            0                     0                1       0
#
#     storm  fire  earthquake  cold  other_weather  direct_report
# id
# 2       0     0           0     0              0              0
# 7       1     0           0     0              0              0
#
# [2 rows x 38 columns]
# id
# 2    direct
# 7    direct
# Name: genre, dtype: object

# %% [markdown]
# ### 2. Write a tokenization function to process your text data

# %%
def tokenize(text):
    tokens = word_tokenize(text)
    lemmatizer = WordNetLemmatizer()

    clean_tokens = []
    for tok in tokens:
        clean_tok = lemmatizer.lemmatize(tok).lower().strip()
        clean_tokens.append(clean_tok)

    return clean_tokens

# %% [markdown]
# ### 3. Build multiples machine learning pipeline
# This machine pipeline should take in the `message` column as input and output classification results on the other 36 categories in the dataset. You may find the [MultiOutputClassifier](http://scikit-learn.org/stable/modules/generated/sklearn.multioutput.MultiOutputClassifier.html) helpful for predicting multiple target variables.
#
# * try other machine learning algorithms
# * add other features besides the TF-IDF

# %%
# Define different pipelines

nlp_pipeline_rf = Pipeline([
                        ('vect', CountVectorizer(tokenizer=tokenize)),
                        ('tfidf', TfidfTransformer()),
                        ('multiclassifier',MultiOutputClassifier(RandomForestClassifier()))
                    ])

nlp_pipeline_knn = Pipeline([
                        ('vect', CountVectorizer(tokenizer=tokenize)),
                        ('tfidf', TfidfTransformer()),
                        ('multiclassifier',MultiOutputClassifier(KNeighborsClassifier()))
                    ])

nlp_pipeline_simple_rf = Pipeline([
                        ('vect', CountVectorizer(tokenizer=tokenize)),
                        ('tfidf', TfidfTransformer()),
                        ('multiclassifier',RandomForestClassifier())
                    ])


nlp_pipeline_simple_lgb = Pipeline([
                        ('tfidfvect', TfidfVectorizer(tokenizer=tokenize)),
                        ('multiclassifier',LGBMClassifier(n_jobs=-1))
                    ])

# %%
pipeline_dict = {'nlp_pipeline_rf': nlp_pipeline_rf, 'nlp_pipeline_knn ': nlp_pipeline_knn, \
                 'nlp_pipeline_simple_rf':nlp_pipeline_simple_rf, 'nlp_pipeline_simple_lgb': nlp_pipeline_simple_lgb}

# %% [markdown]
# ### 4. Train pipeline
# - Split data into train and test sets
# - Train pipeline

# %%
input_X = X['message']
input_Y = Y

X_train, X_test, y_train, y_test = train_test_split(input_X, input_Y, test_size=0.1, random_state=42)

# Sklearn MultiOutputClassifier requires ohe target classes
y_train_ohe = pd.get_dummies(y_train)

# %%
print("Training X & Y shapes {} , {} , ohe y {}".format(X_train.shape, y_train.shape, y_train_ohe.shape))
print("Test X & Y shapes {} , {}".format(X_test.shape, y_test.shape))
# Out:
# Training X & Y shapes (23594,) , (23594,) , ohe y (23594, 3)
# Test X & Y shapes (2622,) , (2622,)

# %%
# set config to diagram for visualizing the pipelines/composite estimators
set_config(display='diagram') #'text'

# cross validation for F1 score
f1_results = {} 

for pipename, pipevalue in pipeline_dict.items() :
    print ("Training pipeline : {} ...".format(pipename))
    display(pipevalue)
    if (pipename != 'nlp_pipeline_simple_lgb'):
        scores = cross_val_score(pipevalue, X_train, y_train_ohe, scoring='f1_weighted', cv=5)
    else:
        scores = cross_val_score(pipevalue, X_train, y_train, scoring='f1_weighted', cv=5)
    f1_results[pipename] = scores.mean()
    print ("Pipeline : {} F1 mean score {}".format(pipename, scores.mean()))
# Out:
# Training pipeline : nlp_pipeline_rf ...
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000001E3593E0D08>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('multiclassifier',
#                  MultiOutputClassifier(estimator=RandomForestClassifier()))])
# Pipeline : nlp_pipeline_rf F1 mean score 0.9526416824907684
# Training pipeline : nlp_pipeline_knn  ...
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000001E3593E0D08>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('multiclassifier',
#                  MultiOutputClassifier(estimator=KNeighborsClassifier()))])
# Pipeline : nlp_pipeline_knn  F1 mean score 0.8278081495937742
# Training pipeline : nlp_pipeline_simple_rf ...
# Pipeline(steps=[('vect',
#                  CountVectorizer(tokenizer=<function tokenize at 0x000001E3593E0D08>)),
#                 ('tfidf', TfidfTransformer()),
#                 ('multiclassifier', RandomForestClassifier())])
# Pipeline : nlp_pipeline_simple_rf F1 mean score 0.9451949296169986
# Training pipeline : nlp_pipeline_simple_lgb ...
# Pipeline(steps=[('tfidfvect',
#                  TfidfVectorizer(tokenizer=<function tokenize at 0x000001E3593E0D08>)),
#                 ('multiclassifier', LGBMClassifier())])
# Pipeline : nlp_pipeline_simple_lgb F1 mean score 0.9653058914448854

# %%
# Results and Best pipeline

best_pipline_name = max(f1_results, key=f1_results.get)

ax = pd.DataFrame.from_dict(f1_results, orient='index').plot.barh(figsize=(12,5))
ax.set_xlabel("CV F1 Mean Scores")
ax.set_ylabel("Pipelines")
ax.set_title('Pipeline Training Results - best results '+ best_pipline_name)
plt.show()

# %%
# Train best pipline
best_pipline = pipeline_dict[best_pipline_name]
best_pipline
#best_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('tfidfvect',
#                  TfidfVectorizer(tokenizer=<function tokenize at 0x000001E3593E0D08>)),
#                 ('multiclassifier', LGBMClassifier())])

# %% [markdown]
# ### 6. Tune Best Model
# Use grid search to find better parameters.
#
# Since this project focuses on code quality, process, and  pipelines, there is no minimum performance metric needed to pass. However, make sure to fine tune your models for accuracy, precision and recall to make your project stand out - especially for your portfolio!

# %%
myscoring = make_scorer(f1_score,average='weighted')

parameters = {
    'tfidfvect__ngram_range': ((1, 1), (1, 2)),
    'tfidfvect__max_df': (0.5, 0.75, 1.0),
    'tfidfvect__max_features': (None, 100, 500, 2000),
    'multiclassifier__learning_rate': [0.01, 0.1 , 0.5, 0,8],
    'multiclassifier__max_depth': [5, 10, 20],
#    'multiclassifier__num_leaves': 50,
#      'clf__min_samples_leaf': [1, 2, 4],
#      'clf__min_samples_split': [2, 5, 10],
    'multiclassifier__n_estimators': [100, 200, 400, 800 , 1000] 
    }

# create grid search object
search = RandomizedSearchCV(best_pipline, parameters, scoring=myscoring, n_jobs=-1)

result = search.fit(X_train, y_train)

# summarize result
print('Best Score: %s' % result.best_score_)
print('Best Hyperparameters: %s' % result.best_params_)
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# Best Score: 0.9636271288404016
# Best Hyperparameters: {'tfidfvect__ngram_range': (1, 1), 'tfidfvect__max_features': None, 'tfidfvect__max_df': 0.75, 'multiclassifier__n_estimators': 1000, 'multiclassifier__max_depth': 20, 'multiclassifier__learning_rate': 0.5}

# %%
#Print grid search CV results
means = search.cv_results_['mean_test_score']
stds = search.cv_results_['std_test_score']
params = search.cv_results_['params']
for mean, stdev, param in zip(means, stds, params):
    display("param search results -> %f (%f) with: %r" % (mean, stdev, param))
# Out:
# "param search results -> 0.943042 (0.002763) with: {'tfidfvect__ngram_range': (1, 1), 'tfidfvect__max_features': None, 'tfidfvect__max_df': 0.5, 'multiclassifier__n_estimators': 100, 'multiclassifier__max_depth': 5, 'multiclassifier__learning_rate': 0.1}"
# "param search results -> 0.923417 (0.005406) with: {'tfidfvect__ngram_range': (1, 1), 'tfidfvect__max_features': 100, 'tfidfvect__max_df': 0.75, 'multiclassifier__n_estimators': 1000, 'multiclassifier__max_depth': 20, 'multiclassifier__learning_rate': 0.5}"
# "param search results -> 0.908148 (0.005171) with: {'tfidfvect__ngram_range': (1, 2), 'tfidfvect__max_features': 2000, 'tfidfvect__max_df': 0.75, 'multiclassifier__n_estimators': 100, 'multiclassifier__max_depth': 20, 'multiclassifier__learning_rate': 0.01}"
# "param search results -> 0.963627 (0.002529) with: {'tfidfvect__ngram_range': (1, 1), 'tfidfvect__max_features': None, 'tfidfvect__max_df': 0.75, 'multiclassifier__n_estimators': 1000, 'multiclassifier__max_depth': 20, 'multiclassifier__learning_rate': 0.5}"
# "param search results -> 0.941117 (0.004383) with: {'tfidfvect__ngram_range': (1, 1), 'tfidfvect__max_features': 2000, 'tfidfvect__max_df': 1.0, 'multiclassifier__n_estimators': 200, 'multiclassifier__max_depth': 10, 'multiclassifier__learning_rate': 0.01}"
# "param search results -> nan (nan) with: {'tfidfvect__ngram_range': (1, 2), 'tfidfvect__max_features': 2000, 'tfidfvect__max_df': 0.75, 'multiclassifier__n_estimators': 1000, 'multiclassifier__max_depth': 10, 'multiclassifier__learning_rate': 0}"
# "param search results -> 0.951968 (0.002139) with: {'tfidfvect__ngram_range': (1, 2), 'tfidfvect__max_features': 500, 'tfidfvect__max_df': 0.5, 'multiclassifier__n_estimators': 400, 'multiclassifier__max_depth': 10, 'multiclassifier__learning_rate': 0.1}"
# "param search results -> 0.962896 (0.002129) with: {'tfidfvect__ngram_range': (1, 2), 'tfidfvect__max_features': 2000, 'tfidfvect__max_df': 0.5, 'multiclassifier__n_estimators': 200, 'multiclassifier__max_depth': 20, 'multiclassifier__learning_rate': 0.5}"
# "param search results -> 0.923483 (0.005002) with: {'tfidfvect__ngram_range': (1, 2), 'tfidfvect__max_features': 500, 'tfidfvect__max_df': 0.75, 'multiclassifier__n_estimators': 200, 'multiclassifier__max_depth': 20, 'multiclassifier__learning_rate': 0.01}"
# "param search results -> 0.932144 (0.005186) with: {'tfidfvect__ngram_range': (1, 2), 'tfidfvect__max_features': 100, 'tfidfvect__max_df': 1.0, 'multiclassifier__n_estimators': 100, 'multiclassifier__max_depth': 10, 'multiclassifier__learning_rate': 0.5}"

# %%
# Best Model with tuned parameters
set_config(display='text')

best_model_tuned = search.best_estimator_
best_model_tuned
# Out:
# Pipeline(steps=[('tfidfvect',
#                  TfidfVectorizer(max_df=0.75,
#                                  tokenizer=<function tokenize at 0x000001E3593E0D08>)),
#                 ('multiclassifier',
#                  LGBMClassifier(learning_rate=0.5, max_depth=20,
#                                 n_estimators=1000))])

# %% [markdown]
# ### 7. Test your model
# Report the f1 score, precision and recall for each output category of the dataset. You can do this by iterating through the columns and calling sklearn's `classification_report` on each.
#
# Show the accuracy, precision, and recall of the tuned model.

# %%
# Confusion Matrix Plot Params
np.set_printoptions(precision=3)
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(20, 8))
plt.rcParams.update({'font.size': 16})

predictions = best_model_tuned.predict(X_test)
cm = confusion_matrix(y_test, predictions)

# normalized confusion matrix
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


#Display Confusion matrices
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=best_model_tuned.classes_)
ax1.set_title('Confusion Matrix')
disp.plot(cmap=plt.cm.Blues, ax=ax1)

disp_normalized = ConfusionMatrixDisplay(confusion_matrix=cm_normalized, display_labels=best_model_tuned.classes_)
ax2.set_title('Normalized Confusion Matrix')
disp_normalized.plot(cmap=plt.cm.Blues, ax=ax2)

plt.show()

# %%
# Print Classification Report
print(classification_report(y_test, predictions, labels= best_model_tuned.classes_))
# Out:
#               precision    recall  f1-score   support
#
#       direct       0.96      0.96      0.96      1086
#         news       0.98      0.98      0.98      1289
#       social       0.95      0.93      0.94       247
#
#     accuracy                           0.97      2622
#    macro avg       0.96      0.96      0.96      2622
# weighted avg       0.97      0.97      0.97      2622

# %% [markdown]
# ### 8. Model Explainability
#
# Check feature importance and use Lime to understand a bit better how the best model classifies the input text

# %%
# Plot Xtrain labels the transformation part of the pipeline after having applied LSA dimension reduction
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html

def plot_LSA(test_data, test_labels):
        lsa = TruncatedSVD(n_components=2)
        lsa.fit(test_data)
        lsa_scores = lsa.transform(test_data)
        color_mapper = {label:idx for idx,label in enumerate(set(test_labels))}
        color_column = [color_mapper[label] for label in test_labels]
        colors = ['orange','blue','green']
        plt.scatter(lsa_scores[:,0], lsa_scores[:,1], s=8, alpha=.8, c=test_labels, cmap=matplotlib.colors.ListedColormap(colors))
        orange_patch = mpatches.Patch(color='orange', label=best_model_tuned.classes_[0])
        blue_patch = mpatches.Patch(color='blue', label=best_model_tuned.classes_[1])
        green_patch = mpatches.Patch(color='green', label=best_model_tuned.classes_[2])
        plt.legend(handles=[orange_patch, blue_patch, green_patch], prop={'size': 20})
          
X_train_transform = best_model_tuned[:-1].fit_transform(X_train)

fig = plt.figure(figsize=(15, 15))          
plot_LSA(X_train_transform, le.fit_transform(y_train))
plt.show()

# %% [markdown]
# We can observe that the news genre is fairly well concentrated while  the social genre is much more diffused and 'mixed' with the direct genre

# %%
# set-up Lime
limeexplainer = LimeTextExplainer(class_names = best_model_tuned.classes_)

# %%
# pick a random Message and check the predictions
a_message =  X_test.iloc[2]
class_probas = best_model_tuned.predict_proba([a_message])
class_pred = best_model_tuned.predict([a_message])
print ("Message : {} -> classified as {} with class pobas {}".format(a_message,class_pred,''.join(map(str, class_probas))))
# Out:
# Message : Witnesses say 200 to 500 people have so far died of exposure in and around the squalid displacement camps near Herat, while the local branch of the UN High Commissioner for Refugees (UNHCR) says that the 35 centimetres (one foot) of snow had contributed to the deaths of at least 322 people. -> classified as ['news'] with class pobas [6.366e-07 1.000e+00 2.900e-13]

# %%
# check the interpretationby Lime
exp = limeexplainer.explain_instance( a_message ,best_model_tuned.predict_proba, num_features  = 10, top_labels=3)
exp.show_in_notebook()
# Out:
# split() requires a non-empty pattern match.
# <html>
#         <meta http-equiv="content-type" content="text/html; charset=UTF8">
#         <head><script>var lime =
# /******/ (function(modules) { // webpackBootstrap
# /******/ 	// The module cache
# /******/ 	var installedModules = {};
# /******/
# /******/ 	// The require function
# /******/ 	function __webpack_require__(moduleId) {
# /******/
# /******/ 		// Check if module is in cache
# /******/ 		if(installedModules[moduleId])
# /******/ 			return installedModules[moduleId].exports;
# /******/
# /******/ 		// Create a new module (and put it into the cache)
# /******/ 		var module = installedModules[moduleId] = {
# /******/ 			exports: {},
# /******/ 			id: moduleId,
# /******/ 			loaded: false
# /******/ 		};
# /******/
# /******/ 		// Execute the module function
# /******/ 		modules[moduleId].call(module.exports, module, module.exports, __webpack_require__);
# /******/
# /******/ 		// Flag the module as loaded
# /******/ 		module.loaded = true;
# /******/
# /******/ 		// Return the exports of the module
# /******/ 		return module.exports;
# /******/ 	}
# /******/
# /******/
# /******/ 	// expose the modules object (__webpack_modules__)
# /******/ 	__webpack_require__.m = modules;
# /******/
# /******/ 	// expose the module cache
# /******/ 	__webpack_require__.c = installedModules;
# /******/
# /******/ 	// __webpack_public_path__
# /******/ 	__webpack_require__.p = "";
# /******/
# /******/ 	// Load entry module and return exports
# /******/ 	return __webpack_require__(0);
# /******/ })
# /************************************************************************/
# /******/ ([
# /* 0 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	/* WEBPACK VAR INJECTION */(function(global) {'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
# 	exports.PredictedValue = exports.PredictProba = exports.Barchart = exports.Explanation = undefined;
#
# 	var _explanation = __webpack_require__(1);
#
# 	var _explanation2 = _interopRequireDefault(_explanation);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _predict_proba = __webpack_require__(6);
#
# 	var _predict_proba2 = _interopRequireDefault(_predict_proba);
#
# 	var _predicted_value = __webpack_require__(7);
#
# 	var _predicted_value2 = _interopRequireDefault(_predicted_value);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	if (!global._babelPolyfill) {
# 	  __webpack_require__(8);
# 	}
#
# 	__webpack_require__(339);
#
# 	exports.Explanation = _explanation2.default;
# 	exports.Barchart = _bar_chart2.default;
# 	exports.PredictProba = _predict_proba2.default;
# 	exports.PredictedValue = _predicted_value2.default;
# 	//require('style-loader');
# 	/* WEBPACK VAR INJECTION */}.call(exports, (function() { return this; }())))
#
# /***/ }),
# /* 1 */
# /***/ (function(module, exports, __webpack_require__) {
#
# 	'use strict';
#
# 	Object.defineProperty(exports, "__esModule", {
# 	  value: true
# 	});
#
# 	var _slicedToArray = function () { function sliceIterator(arr, i) { var _arr = []; var _n = true; var _d = false; var _e = undefined; try { for (var _i = arr[Symbol.iterator](), _s; !(_n = (_s = _i.next()).done); _n = true) { _arr.push(_s.value); if (i && _arr.length === i) break; } } catch (err) { _d = true; _e = err; } finally { try { if (!_n && _i["return"]) _i["return"](); } finally { if (_d) throw _e; } } return _arr; } return function (arr, i) { if (Array.isArray(arr)) { return arr; } else if (Symbol.iterator in Object(arr)) { return sliceIterator(arr, i); } else { throw new TypeError("Invalid attempt to destructure non-iterable instance"); } }; }();
#
# 	var _d2 = __webpack_require__(2);
#
# 	var _d3 = _interopRequireDefault(_d2);
#
# 	var _bar_chart = __webpack_require__(3);
#
# 	var _bar_chart2 = _interopRequireDefault(_bar_chart);
#
# 	var _lodash = __webpack_require__(4);
#
# 	function _interopRequireDefault(obj) { return obj && obj.__esModule ? obj : { default: obj }; }
#
# 	function _classCallCheck(instance, Constructor) { if (!(instance instanceof Constructor)) { throw new TypeError("Cannot call a class as a function"); } }
#
# 	var Explanation = function () {
# 	  function Explanation(class_names) {
# 	    _classCallCheck(this, Explanation);
#
# 	    this.names = class_names;
# 	    if (class_names.length < 10) {
# 	      this.colors = _d3.default.scale.category10().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category10().domain((0, _lodash.range)(this.names.length));
# 	    } else {
# 	      this.colors = _d3.default.scale.category20().domain(this.names);
# 	      this.colors_i = _d3.default.scale.category20().domain((0, _lodash.range)(this.names.length));
# 	    }
# 	  }
# 	  // exp: [(feature-name, weight), ...]
# 	  // label: int
# 	  // div: d3 selection
#
#
# 	  Explanation.prototype.show = function show(exp, label, div) {
# 	    var svg = div.append('svg').style('width', '100%');
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    var names = ['NOT ' + this.names[label], this.names[label]];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	      names = this.names;
# 	    }
# 	    var plot = new _bar_chart2.default(svg, exp, true, names, colors, true, 10);
# 	    svg.style('height', plot.svg_height + 'px');
# 	  };
# 	  // exp has all ocurrences of words, with start index and weight:
# 	  // exp = [('word', 132, -0.13), ('word3', 111, 1.3)
#
#
# 	  Explanation.prototype.show_raw_text = function show_raw_text(exp, label, raw, div) {
# 	    var opacity = arguments.length > 4 && arguments[4] !== undefined ? arguments[4] : true;
#
# 	    //let colors=['#5F9EA0', this.colors(this.exp['class'])];
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var word_lists = [[], []];
# 	    var max_weight = -1;
# 	    var _iteratorNormalCompletion = true;
# 	    var _didIteratorError = false;
# 	    var _iteratorError = undefined;
#
# 	    try {
# 	      for (var _iterator = exp[Symbol.iterator](), _step; !(_iteratorNormalCompletion = (_step = _iterator.next()).done); _iteratorNormalCompletion = true) {
# 	        var _step$value = _slicedToArray(_step.value, 3),
# 	            word = _step$value[0],
# 	            start = _step$value[1],
# 	            weight = _step$value[2];
#
# 	        if (weight > 0) {
# 	          word_lists[1].push([start, start + word.length, weight]);
# 	        } else {
# 	          word_lists[0].push([start, start + word.length, -weight]);
# 	        }
# 	        max_weight = Math.max(max_weight, Math.abs(weight));
# 	      }
# 	    } catch (err) {
# 	      _didIteratorError = true;
# 	      _iteratorError = err;
# 	    } finally {
# 	      try {
# 	        if (!_iteratorNormalCompletion && _iterator.return) {
# 	          _iterator.return();
# 	        }
# 	      } finally {
# 	        if (_didIteratorError) {
# 	          throw _iteratorError;
# 	        }
# 	      }
# 	    }
#
# 	    if (!opacity) {
# 	      max_weight = 0;
# 	    }
# 	    this.display_raw_text(div, raw, word_lists, colors, max_weight, true);
# 	  };
# 	  // exp is list of (feature_name, value, weight)
#
#
# 	  Explanation.prototype.show_raw_tabular = function show_raw_tabular(exp, label, div) {
# 	    div.classed('lime', true).classed('table_div', true);
# 	    var colors = ['#5F9EA0', this.colors_i(label)];
# 	    if (this.names.length == 2) {
# 	      colors = [this.colors_i(0), this.colors_i(1)];
# 	    }
# 	    var table = div.append('table');
# 	    var thead = table.append('tr');
# 	    thead.append('td').text('Feature');
# 	    thead.append('td').text('Value');
# 	    thead.style('color', 'black').style('font-size', '20px');
# 	    var _iteratorNormalCompletion2 = true;
# 	    var _didIteratorError2 = false;
# 	    var _iteratorError2 = undefined;
#
# 	    try {
# 	      for (var _iterator2 = exp[Symbol.iterator](), _step2; !(_iteratorNormalCompletion2 = (_step2 = _iterator2.next()).done); _iteratorNormalCompletion2 = true) {
# 	        var _step2$value = _slicedToArray(_step2.value, 3),
# 	            fname = _step2$value[0],
# 	            value = _step2$value[1],
# 	            weight = _s

# %% [markdown]
# ### 9. Investigate miss-classifications

# %%
# Build a Dataframe used to identify missclassified Genres, add the LSA (2 components score)
X_test_transform = best_model_tuned[:-1].fit_transform(X_test)
lsa = TruncatedSVD(n_components=2)
lsa.fit(X_test_transform)
lsa_scores = lsa.transform(X_test_transform)
frame = { 'Message': X_test, 'Lsa Score 1': lsa_scores[:,0], 'Lsa Score 2': lsa_scores[:,1], 'Labels' : y_test, 'Predictions' : predictions} 
res_df = pd.DataFrame(frame)
res_df['PredictionResult'] = res_df['Labels'] == res_df['Predictions']
res_df['Message'] = res_df['Message'].str.replace('.','<br>')

res_df.head()
# Out:
#                                                  Message  Lsa Score 1  \
# id
# 8896     Please ,give me some help<br>Thanks before<br>      0.123455
# 29242  A positive development is that cooling has bee...     0.146296
# 25723  Witnesses say 200 to 500 people have so far di...     0.256638
# 21580  The 15-nation Economic Community of West Afric...     0.137718
# 1579   and in addition what time will it be possible ...     0.262891
#
#        Lsa Score 2  Labels Predictions  PredictionResult
# id
# 8896      0.072792  direct      direct              True
# 29242    -0.070824    news        news              True
# 25723    -0.158525    news        news              True
# 21580    -0.094601    news        news              True
# 1579      0.065333  direct      direct              True

# %%
# Show Miss Classified Message
col = ['Message','Labels','Predictions']
mask = res_df['PredictionResult'] == False
res_df[mask][col]
# Out:
#                                                  Message  Labels Predictions
# id
# 10403  They say there is a hurrican ,would it be star...  direct        news
# 7700                                   paklascencion##s   direct      social
# 10970  there was a earthquake at cap haitien anorth h...  direct      social
# 12181  Possible 140 mph winds <br><br> <br>Hurricane ...  social      direct
# 14808  Remember when I didn't have to evacuate my apa...  social      direct
# ...                                                  ...     ...         ...
# 27655  This price increase, even though small, is une...    news      direct
# 26430  But where had she got the money to buy the foo...    news      direct
# 2617   bandit are taking over Gonaives<br> they are a...  direct        news
# 12093  I 'm safe , I 'm alive <br><br> <br>I 'm here<...  social      direct
# 5357   wow clouds started to come up the sky,but the ...  direct        news
#
# [82 rows x 3 columns]

# %%
# PLot all test set messages, highlight the miss-classified messages with an X
symbols = ['circle', 'x']

fig = px.scatter(res_df, x="Lsa Score 1", y="Lsa Score 2", color="Labels", hover_data=['Message'],
                 width=1000, height=800, title="Test Set - LSA w/ 2 Components",  
                 symbol = res_df['PredictionResult'], symbol_sequence=symbols, 
                 color_discrete_sequence=px.colors.qualitative.G10)

#fig.update_traces(marker_symbol="x", selector=dict(mode='markers'))
fig.show()
# Out:
# <div>                            <div id="79291a36-8b3f-4c7b-8e44-76c366345dd3" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("79291a36-8b3f-4c7b-8e44-76c366345dd3")) {                    Plotly.newPlot(                        "79291a36-8b3f-4c7b-8e44-76c366345dd3",                        [{"customdata": [["Please ,give me some help<br>Thanks before<br> "], ["and in addition what time will it be possible for me to sleep in my house?"], ["NOTES: it's not a important message<br>"], ["NOTES: This message is not important<br>cause this person ie playing"], ["I need to get information about the weather to day<br> "], ["our houses got destroyed<br>can you help us "], ["TAKE AWAY THE DIRT WHAT IS THAT MEANS? "], ["I am greeting you in the name of the lord<br> This morning I have a question I would like to ask if it doesn't bother you and a few more I would like clarified<br> Is it possible ? and birthday of? "], ["Do each haitian make money less than the money hi can eat each day, it's not a help but it's a way to continue with operating system<br> "], ["pity for makonb, did you forget this district?"], ["is there no aftershock again? "], ["Good morning I don't have a home Can you please give me and my family food and also a tent<br> "], ["good morning my brother I am tiblan I ask you to pass for the music is titlle water from miragoane I always ask u to great me cause I am a fanatic silence ok my animator "], ["Please BANMA ti? on information on cash for work "], ["How avoid dengue and yellow fever<br> "], ["We want to be beneficiary of the donations "], ["4636, I want to let you know that I have space to have more than 50 people sleep "], ["Sir or madam, I'm hungry, I cannot stand because I'm very hungry, if you could share the food, it would benefit the population, thanks"], ["WE WANT TO EAT IN GRESSIER SEND TENTS AND FOOD AND MEDICAMENTS "], ["I'm the only one I left in my family<br> I have nothing to do,please help me<br>  "], ["<br><br> one assurance<br> This is how nature has judged us<br> Me and my family<br><br> "], ["are the giving people with residency status visas to go to the states yet<br>"], ["Tell me what should I do to activate internet on my V3 phone "], ["May I know if someone is 60 years old can participate in the vaccination campaign<br> "], ["Soap , antibacterial handwipes , baby wipes , hand sanitizer , painkillers"], ["Nounoune arrived at home<br> Our Jewovah 's sisters are waiting for you "], ["During the quake my head was hit hard<br> Since then it gives me lots of problems<br> Something is wrong<br> I cannot see well<br> I would like to now where I can find help<br> "], ["Where actually the persons can rescue their Identification National's card? "], ["I lost the PIM pap padap help me svp<br>Merci "], ["I live in Saint Marc<br> My house is destroyed<br> My neighborhood needs food and money and I need w?okt??ou "], ["If you think with me like this that mean there are serious things that undertake inside of the country<br>I'm a young about 31 years old whose jobless<br> I would like to hire<br> "], ["Want to know what the government said about the earthquake "], ["food, we have no water<br> We are in the streets and we have sick peoplel with us "], ["Information about the earthquake in Haiti"], ["The SMS: in the provinces, who will help school, because I said I would like to know whether I will be able to end the year school ok thank you<br> "], ["in the villages of jam gulab pahore and haidar pahore nearly 50 houses have been collapsed and ruined because of halia flood<br> we don't have houses to live<br>chief minister of punjab gave a blanket per family and nothing else we got<br>"], ["We are at 13 ruelle Larose<br> We have nothing to eat<br> We have no water, no tent w ...

# %%
# PLot the miss-classified messages
symbols = ['x']

fig = px.scatter(res_df[mask], x="Lsa Score 1", y="Lsa Score 2", color="Labels", hover_data=['Message','Labels','Predictions'],
                 width=1000, height=800, title="Test Set - LSA w/ 2 Components",  
                  symbol_sequence=symbols, 
                 color_discrete_sequence=px.colors.qualitative.G10)

fig.update_traces(mode='markers')
fig.show()
# Out:
# <div>                            <div id="c38d4183-e11a-4164-8a46-91488f642f51" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c38d4183-e11a-4164-8a46-91488f642f51")) {                    Plotly.newPlot(                        "c38d4183-e11a-4164-8a46-91488f642f51",                        [{"customdata": [["They say there is a hurrican ,would it be stared by rain<br> ", "direct", "news"], ["paklascencion##s ", "direct", "social"], ["there was a earthquake at cap haitien anorth haiti in 1842,the assessment was rest unknown<br> ", "direct", "social"], ["My wife is pregnant, she was hit by a block on Jan 12th, she went to the hospital and they said the baby has been moved<br> She's at the hospital called St<br> Therese Miragwan, he doesn't have any money to get her ", "direct", "news"], ["THE GOUVERNMENT CAANNOT TAKE CARE OF THIS SITUATION,THEY ONLY OBSERVE LIKE THE REST OF US,BUT DO LIKE IF THEY WERE DOING SOMETHING ", "direct", "news"], ["CYCLONE<br>J EXPECT THE ANSWER PATIENT<br> ", "direct", "news"], ["The quake happened at an elevated level<br> There are houses that are cracked<br> ", "direct", "news"], ["Big storm <br><br> 2 days off <br><br> still ca n't sleep <br><br> grr", "direct", "social"], ["Would like information from Canada, Senegal, the USA, and France for refuge<br>", "direct", "news"], ["It's Over in Gressier<br> The population in the area - Incomplete", "direct", "news"], ["How the review will be conducted this year<br> ", "direct", "news"], ["we ask to contact the police to come check a machine brown located in the lobby of the Hotel El Hancho''''because there are armed people in the car ", "direct", "news"], ["Peanut butter and jelly sandwiches Apples", "direct", "news"], ["Something I witnessed at 6 o'clock at the Centre d'hbergement in Damien: The Americans expelled/kicked out all the earthquake victims<br> ", "direct", "social"], ["This hurricane better actually happen <br><br> im in need of some serious down time <br><br> lmao", "direct", "social"], ["Have they stopped to help and their disaster ", "direct", "news"], ["It will be really important to think with the country which is held by making back make another experiment with Obama by giving him the country<br> ", "direct", "news"], ["do the mosquitoes ONG gave are the insecticide which prevent from them to sting somebody is sleeping under it can die them too ", "direct", "news"], ["Total 50 items : canned beans and vegetables , canned stews and chilies , packaged turkey dogs , instant ( hydratable/microwave ) mac n cheese , noodles n stroganoff , boxed instant oatmeal and other cereals , misc <br> similar packaged items <br>", "direct", "news"], ["In the Pyron area (Petionville-Tomasin) ", "direct", "news"], ["our homes have colapsed due to breaches in Manchar lake and we r now homeless plz save our children from bitter cold<br>", "direct", "news"], ["HELP!!THEY ARE SHOOTING ON THE WAY TO ''FRERES'' BY THE IRON BRIDGE SINCE YESTERDAY NIGHT HURRY!!!! SEND SOLDIERS NOW ", "direct", "news"], ["Definitely ate about 75 % of my emergency food for Hurricane Sandy <br> That 's why I would never survive in a major disaster <br><br>", "direct", "social"], ["I need a tente //   / / // @ @   @ to sleep happy<br><br>I sleep too much in the well stars ", "direct", "social"], ["<br> <br><br> I camping gaz cooker<br> <br><br> ( not sure )<br> <br> For a populatio of more than 5000 people/family<br> From comity for mangaing repair from earthquake", "direct", "social"], ["people of Anse Rouge are dying of hunger and thirst<br> ", "direct", "news"], ["I am a chef and offer my services at a food bank or other facility that would provide food for relief victims of storm Sandy", "direct", "social"], ["Storm at sacred heart of jesus", " ...

# %% [markdown]
# ### 10. Export your model as a pickle file

# %%
import pickle

model_dir = 'models/'

#Get the date to time stamp model
today = datetime.now()
timestamp = today.strftime("%b-%d-%y-%Hh%M")

model_file = best_pipline_name+'-'+timestamp+'.pkl'
print("Saving model {} to directory {}".format(model_file,model_dir))
pickle.dump(best_model_tuned, open(model_dir+model_file, 'wb'))
# Out:
# Saving model nlp_pipeline_simple_lgb-Feb-08-21-10h05.pkl to directory models/

# %%
# !dir models
# Out:
#  Volume in drive E is DATA
#  Volume Serial Number is 6E98-6AE7
#
#  Directory of E:\GitHub\Disaster-Recovery-Message_Classification\models
#
# 02/08/2021  10:05 AM    <DIR>          .
# 02/08/2021  10:05 AM    <DIR>          ..
# 02/04/2021  07:51 PM        14,132,020 nlp_pipeline_simple_gb.pkl
# 02/06/2021  04:10 PM        14,740,184 nlp_pipeline_simple_gbm.pkl
# 02/06/2021  06:25 PM         7,216,797 nlp_pipeline_simple_gbm2.pkl
# 02/08/2021  10:04 AM         8,670,143 nlp_pipeline_simple_lgb-Feb-08-21-10h04.pkl.pkl
# 02/08/2021  10:05 AM         8,670,143 nlp_pipeline_simple_lgb-Feb-08-21-10h05.pkl
# 02/08/2021  10:03 AM         8,670,143 nlp_pipeline_simple_lgb.pkl
#                6 File(s)     62,099,430 bytes
#                2 Dir(s)  1,836,385,259,520 bytes free

# %% [markdown]
# ### 10. Use this notebook to complete `train.py`
# Use the template file attached in the Resources folder to write a script that runs the steps above to create a database and export a model based on a new dataset specified by the user.
